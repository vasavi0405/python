# %%
pip install beautifulsoup4 lxml
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
from bs4 import BeautifulSoup as BS
import pandas as pd
import requests
import webbrowser
import urllib.request
def getReviews(url):
    req = urllib.request.Request(url)
    req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0')
    req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
    req.add_header('Accept-Language', 'en-US,en;q=0.5')
    response = urllib.request.urlopen(req)
    html_code = response.read().decode('utf-8')
    soup=BS(html_code,'html.parser')
    totalReviews=soup.find('span',class_='biGQs _P pZUbB KxBGd').text[:-8].replace(',','')
    hotelName=soup.find('h1',id='HEADING').text
    reviewHeads=[i.text for i in soup.find_all('span',class_='JbGkU Cj')]
    reviewContent=[i.text for i in soup.find_all('span',class_='orRIx Ci _a C')]
    reviewerNdate = [i.text for i in soup.find_all('div', class_='tVWyV _Z o S4 H3 Ci') if 'wrote a review' in i.text]
    reviewerandDate=[]
    for i in reviewerNdate:
        reviewerandDate.append(i.split('wrote a review '))
    finalDate=[]
    finalreviewer=[]
    for i in reviewerandDate:
        finalDate.append(i[1])
        finalreviewer.append(i[0])
    ratings=[i.find('title').text[0:3] for i in soup.find_all('div',class_='kmMXA _T Gi')]
    tempHotelLocation= [i.text for i in soup.find_all('span',class_='biGQs _P pZUbB KxBGd')]
    hotelLocation=tempHotelLocation[1]
    df = pd.DataFrame({
        'Hotel Name': hotelName,
        'Hotel Location': hotelLocation,
        'Reviewer': finalreviewer,
        'Rating':ratings,
        'Date of Review': finalDate,
        'Review':reviewHeads,
        'Complete Review':reviewContent
    })
    return [df,totalReviews,hotelName,hotelLocation]

def getPureReviews(url,hotelName,hotelLocation):
    req = urllib.request.Request(url)
    req.add_header('User-Agent', 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:106.0) Gecko/20100101 Firefox/106.0')
    req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
    req.add_header('Accept-Language', 'en-US,en;q=0.5')
    response = urllib.request.urlopen(req)
    html_code = response.read().decode('utf-8')
    soup=BS(html_code,'html.parser')
    reviewHeads=[i.text for i in soup.find_all('span',class_='JbGkU Cj')]
    reviewContent=[i.text for i in soup.find_all('span',class_='orRIx Ci _a C')]
    reviewerNdate = [i.text for i in soup.find_all('div', class_='tVWyV _Z o S4 H3 Ci') if 'wrote a review' in i.text]
    reviewerandDate=[]
    for i in reviewerNdate:
        reviewerandDate.append(i.split('wrote a review '))
    finalDate=[]
    finalreviewer=[]
    for i in reviewerandDate:
        finalDate.append(i[1])
        finalreviewer.append(i[0])
    ratings=[i.find('title').text[0:3] for i in soup.find_all('div',class_='kmMXA _T Gi')]
    df = pd.DataFrame({
        'Hotel Name': hotelName,
        'Hotel Location': hotelLocation,
        'Reviewer': finalreviewer,
        'Rating':ratings,
        'Date of Review': finalDate,
        'Review':reviewHeads,
        'Complete Review':reviewContent
    })
    return df

# %%
url='https://www.tripadvisor.in/Hotel_Review-g297698-d3633245-Reviews-Mulia_Resort-Nusa_Dua_Benoa_South_Kuta_Bali.html'
split_url = url.split("Reviews-")
first_part = split_url[0] + "Reviews-or"
second_part = "-" + split_url[1]
result = getReviews(url)
df=result[0]
totalReviews=result[1]
hotelName=result[2]
hotelLocation=result[3]
urls = [f"{first_part}{i}{second_part}" for i in range(10, int(totalReviews)-10, 10)]
for i in urls:
    newdf=getPureReviews(i,hotelName,hotelLocation)
    df = pd.concat([df, newdf], ignore_index=True)

df.to_excel('trial1.xlsx', index=False, engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-5077826c215c> in <cell line: 11>()
#      10 urls = [f"{first_part}{i}{second_part}" for i in range(10, int(totalReviews)-10, 10)]
#      11 for i in urls:
# ---> 12     newdf=getPureReviews(i,hotelName,hotelLocation)
#      13     df = pd.concat([df, newdf], ignore_index=True)
#      14
#
# <ipython-input-7-c08dffb02ab8> in getPureReviews(url, hotelName, hotelLocation)
#      44     req.add_header('Accept', 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8')
#      45     req.add_header('Accept-Language', 'en-US,en;q=0.5')
# ---> 46     response = urllib.request.urlopen(req)
#      47     html_code = response.read().decode('utf-8')
#      48     soup=BS(html_code,'html.parser')
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#     527         return response
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     632         # request was successfully received, understood, and accepted.
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#     636
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     561         if http_err:
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#     565 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     494         for handler in handlers:
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#     498                 return result
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     641 class HTTPDefaultErrorHandler(BaseHandler):
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#     645 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
df
# Out:
#       Hotel Name                                     Hotel Location  \
# 0   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 1   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 2   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 3   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 4   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 5   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 6   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 7   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 8   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 9   Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 10  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 11  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 12  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 13  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 14  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 15  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 16  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 17  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 18  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 19  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 20  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 21  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 22  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 23  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 24  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 25  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 26  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 27  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 28  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 29  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 30  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 31  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 32  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 33  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 34  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 35  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 36  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 37  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 38  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 39  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 40  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 41  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 42  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 43  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 44  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 45  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 46  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 47  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 48  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 49  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 50  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 51  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 52  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 53  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 54  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 55  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 56  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 57  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 58  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
# 59  Mulia Resort  Jalan Raya Nusa Dua Selatan, Nusa Dua, Benoa 8...
#
#                Reviewer Rating Date of Review  \
# 0       aandsaustralia     5.0       Nov 2023
# 1         Ozmandapanda     5.0       Jan 2020
# 2    FrequentTraveler9     5.0       Mar 2022
# 3        Sinta Jakarta     5.0       Mar 2022
# 4             Hian Ong     4.0       Feb 2020
# 5                  HJP     4.0       Jan 2020
# 6          erictan1986     5.0       Jan 2022
# 7              Danti P     3.0       Oct 2022
# 8           Ifan Henry     5.0       Mar 2022
# 9               Kurt L     4.0       Mar 2020
# 10       kevinwW5413CI     5.0       Jan 2020
# 11        sofia adler🌸     3.0       Feb 2020
# 12  Odyssey52146433316     1.0       Jul 2023
# 13            233Karen     5.0       Feb 2023
# 14           Akihiromd     5.0       Nov 2020
# 15            Nathan W     5.0       Apr 2023
# 16  The Honey Dreamers     5.0       Dec 2020
# 17              Jane S     5.0      Sept 2021
# 18        smilegirl949     4.0       Dec 2022
# 19           Hidayat T     4.0       Dec 2021
# 20            Cherie M     5.0       Jan 2024
# 21                miss     5.0       Dec 2022
# 22         chelnugroho     5.0       May 2022
# 23             Paula W     4.0       Feb 2024
# 24          robmaizels     4.0       Jan 2020
# 25               sov09     5.0       Nov 2023
# 26         Sudarsono S     5.0       Jun 2022
# 27             Zahra F     5.0       Oct 2021
# 28         riyanwiguna     5.0       Mar 2022
# 29              Anti D     1.0       Dec 2020
